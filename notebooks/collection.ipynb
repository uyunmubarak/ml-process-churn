# %%
import pandas as pd
import copy
from sklearn.model_selection import train_test_split
import util
from util import load_config, pickle_dump, pickle_load

# %%
config = load_config()

# %%
def read_raw_df(raw_data_path: str) -> pd.DataFrame:
    df = pd.read_csv(raw_data_path, index_col=0)

    df.drop(config["drop_columns"], axis=1, inplace=True)

    return df

# %%
config["predictors"][1:15]
# Out:
# ['days_since_last_login',
#  'points_in_wallet',
#  'gender',
#  'region_category',
#  'membership_category',
#  'joined_through_referral',
#  'preferred_offer_types',
#  'medium_of_operation',
#  'internet_option',
#  'used_special_discount',
#  'offer_application_preference',
#  'past_complaint',
#  'complaint_status',
#  'feedback']

# %%
df = read_raw_df(config["raw_dataset_path"])
df
# Out:
#        age gender region_category  membership_category  \
# 0       18      F         Village  Platinum Membership
# 1       32      F            City   Premium Membership
# 2       44      F            Town        No Membership
# 3       37      M            City        No Membership
# 4       31      F            City        No Membership
# ...    ...    ...             ...                  ...
# 36987   46      F             NaN     Basic Membership
# 36988   29      F            Town     Basic Membership
# 36989   23      F             NaN     Basic Membership
# 36990   53      M         Village  Platinum Membership
# 36991   35      M            Town    Silver Membership
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                          No     Gift Vouchers/Coupons                   ?
# 1                           ?     Gift Vouchers/Coupons             Desktop
# 2                         Yes     Gift Vouchers/Coupons             Desktop
# 3                         Yes     Gift Vouchers/Coupons             Desktop
# 4                          No  Credit/Debit Card Offers          Smartphone
# ...                       ...                       ...                 ...
# 36987                      No  Credit/Debit Card Offers             Desktop
# 36988                      No            Without Offers          Smartphone
# 36989                     Yes     Gift Vouchers/Coupons             Desktop
# 36990                      No     Gift Vouchers/Coupons          Smartphone
# 36991                      No     Gift Vouchers/Coupons             Desktop
#
#       internet_option  days_since_last_login  points_in_wallet  \
# 0               Wi-Fi                     17        781.750000
# 1         Mobile_Data                     16               NaN
# 2               Wi-Fi                     14        500.690000
# 3         Mobile_Data                     11        567.660000
# 4         Mobile_Data                     20        663.060000
# ...               ...                    ...               ...
# 36987           Wi-Fi                      2        639.510000
# 36988           Wi-Fi                     13        527.990000
# 36989           Wi-Fi                     12        680.470000
# 36990     Mobile_Data                     15        197.264414
# 36991     Mobile_Data                     15        719.970000
#
#       used_special_discount offer_application_preference past_complaint  \
# 0                       Yes                          Yes             No
# 1                       Yes                           No            Yes
# 2                        No                          Yes            Yes
# 3                        No                          Yes            Yes
# 4                        No                          Yes            Yes
# ...                     ...                          ...            ...
# 36987                    No                          Yes            Yes
# 36988                   Yes                           No             No
# 36989                    No                          Yes            Yes
# 36990                   Yes                          Yes             No
# 36991                   Yes                           No             No
#
#                complaint_status                  feedback  churn_risk_score
# 0                Not Applicable  Products always in Stock                 0
# 1                        Solved     Quality Customer Care                 0
# 2           Solved in Follow-up              Poor Website                 1
# 3                      Unsolved              Poor Website                 1
# 4                        Solved              Poor Website                 1
# ...                         ...                       ...               ...
# 36987  No Information Available       No reason specified                 1
# 36988            Not Applicable     Poor Customer Service                 1
# 36989                  Unsolved              Poor Website                 1
# 36990            Not Applicable       No reason specified                 0
# 36991            Not Applicable     Quality Customer Care                 0
#
# [36992 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# age                                0
# gender                             0
# region_category                 5428
# membership_category                0
# joined_through_referral            0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# days_since_last_login              0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
df.shape
# Out:
# (36992, 16)

# %%
pickle_dump(df, config["raw_df_path"])
# Out:
# ['../data/processed/raw_df.pkl']

# %%
df_after_drop = pickle_load(config["raw_df_path"])
df_after_drop
# Out:
#        age gender region_category  membership_category  \
# 0       18      F         Village  Platinum Membership
# 1       32      F            City   Premium Membership
# 2       44      F            Town        No Membership
# 3       37      M            City        No Membership
# 4       31      F            City        No Membership
# ...    ...    ...             ...                  ...
# 36987   46      F             NaN     Basic Membership
# 36988   29      F            Town     Basic Membership
# 36989   23      F             NaN     Basic Membership
# 36990   53      M         Village  Platinum Membership
# 36991   35      M            Town    Silver Membership
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                          No     Gift Vouchers/Coupons                   ?
# 1                           ?     Gift Vouchers/Coupons             Desktop
# 2                         Yes     Gift Vouchers/Coupons             Desktop
# 3                         Yes     Gift Vouchers/Coupons             Desktop
# 4                          No  Credit/Debit Card Offers          Smartphone
# ...                       ...                       ...                 ...
# 36987                      No  Credit/Debit Card Offers             Desktop
# 36988                      No            Without Offers          Smartphone
# 36989                     Yes     Gift Vouchers/Coupons             Desktop
# 36990                      No     Gift Vouchers/Coupons          Smartphone
# 36991                      No     Gift Vouchers/Coupons             Desktop
#
#       internet_option  days_since_last_login  points_in_wallet  \
# 0               Wi-Fi                     17        781.750000
# 1         Mobile_Data                     16               NaN
# 2               Wi-Fi                     14        500.690000
# 3         Mobile_Data                     11        567.660000
# 4         Mobile_Data                     20        663.060000
# ...               ...                    ...               ...
# 36987           Wi-Fi                      2        639.510000
# 36988           Wi-Fi                     13        527.990000
# 36989           Wi-Fi                     12        680.470000
# 36990     Mobile_Data                     15        197.264414
# 36991     Mobile_Data                     15        719.970000
#
#       used_special_discount offer_application_preference past_complaint  \
# 0                       Yes                          Yes             No
# 1                       Yes                           No            Yes
# 2                        No                          Yes            Yes
# 3                        No                          Yes            Yes
# 4                        No                          Yes            Yes
# ...                     ...                          ...            ...
# 36987                    No                          Yes            Yes
# 36988                   Yes                           No             No
# 36989                    No                          Yes            Yes
# 36990                   Yes                          Yes             No
# 36991                   Yes                           No             No
#
#                complaint_status                  feedback  churn_risk_score
# 0                Not Applicable  Products always in Stock                 0
# 1                        Solved     Quality Customer Care                 0
# 2           Solved in Follow-up              Poor Website                 1
# 3                      Unsolved              Poor Website                 1
# 4                        Solved              Poor Website                 1
# ...                         ...                       ...               ...
# 36987  No Information Available       No reason specified                 1
# 36988            Not Applicable     Poor Customer Service                 1
# 36989                  Unsolved              Poor Website                 1
# 36990            Not Applicable       No reason specified                 0
# 36991            Not Applicable     Quality Customer Care                 0
#
# [36992 rows x 16 columns]

# %%
def split_data(dataframe: pd.DataFrame)->pd.DataFrame:
    df = copy.deepcopy(dataframe)

    x = df[config["predictors"]]
    y = df[config["label"]]

    x_train, x_test, y_train, y_test = train_test_split(
        x, y,
        test_size = config["test_size"],
        random_state = 42,
        stratify = y)

    x_valid, x_test, y_valid, y_test = train_test_split(
        x_test, y_test,
        test_size = config["valid_size"],
        random_state = 42,
        stratify = y_test
    )
    return x_train, x_valid, x_test, y_train, y_valid, y_test

# %%
x_train, x_valid, x_test, y_train, y_valid, y_test = split_data(df)

# %%
print(f"X_train shape: {x_train.shape}")
print(f"X_test shape: {x_test.shape}")
print(f"X_valid shape:{x_valid.shape}")

print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
print(f"y_valid shape: {y_valid.shape}")
# Out:
# X_train shape: (25894, 15)
# X_test shape: (5549, 15)
# X_valid shape:(5549, 15)
# y_train shape: (25894, 1)
# y_test shape: (5549, 1)
# y_valid shape: (5549, 1)

# %%
y_train
# Out:
#        churn_risk_score
# 36181                 0
# 31548                 1
# 27354                 1
# 25931                 1
# 12225                 1
# ...                 ...
# 14579                 0
# 6498                  0
# 21879                 1
# 23008                 1
# 134                   0
#
# [25894 rows x 1 columns]

# %%
# reset index
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

x_valid = x_valid.reset_index(drop=True)
y_valid = y_valid.reset_index(drop=True)

x_test = x_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
x_train.head()
# Out:
#    age  days_since_last_login  points_in_wallet gender region_category  \
# 0   18                     10        738.460000      M            Town
# 1   39                     22        249.450376      M             NaN
# 2   34                     12        568.140000      F            City
# 3   56                     18        716.410000      M         Village
# 4   23                     10        671.240000      F         Village
#
#   membership_category joined_through_referral     preferred_offer_types  \
# 0     Gold Membership                     Yes     Gift Vouchers/Coupons
# 1   Silver Membership                     Yes            Without Offers
# 2       No Membership                      No            Without Offers
# 3    Basic Membership                      No  Credit/Debit Card Offers
# 4    Basic Membership                      No            Without Offers
#
#   medium_of_operation internet_option used_special_discount  \
# 0                Both     Mobile_Data                    No
# 1             Desktop     Mobile_Data                    No
# 2          Smartphone     Mobile_Data                    No
# 3             Desktop           Wi-Fi                   Yes
# 4             Desktop     Fiber_Optic                   Yes
#
#   offer_application_preference past_complaint          complaint_status  \
# 0                          Yes             No            Not Applicable
# 1                          Yes            Yes       Solved in Follow-up
# 2                          Yes            Yes                  Unsolved
# 3                           No            Yes  No Information Available
# 4                           No             No            Not Applicable
#
#                 feedback
# 0           Too many ads
# 1           Poor Website
# 2  Poor Customer Service
# 3           Too many ads
# 4  Poor Customer Service

# %%
x_train.shape, x_valid.shape, x_test.shape, y_train.shape,\
    y_valid.shape, y_test.shape
# Out:
# ((25894, 15), (5549, 15), (5549, 15), (25894, 1), (5549, 1), (5549, 1))

# %%
y_valid
# Out:
#       churn_risk_score
# 0                    1
# 1                    0
# 2                    1
# 3                    0
# 4                    0
# ...                ...
# 5544                 0
# 5545                 1
# 5546                 0
# 5547                 0
# 5548                 1
#
# [5549 rows x 1 columns]

# %%
pickle_dump(x_train, config["train_set_path"][0])
pickle_dump(y_train, config["train_set_path"][1])

pickle_dump(x_valid, config["valid_set_path"][0])
pickle_dump(y_valid, config["valid_set_path"][1])

pickle_dump(x_test, config["test_set_path"][0])
pickle_dump(y_test, config["test_set_path"][1])
# Out:
# ['../data/processed/y_test.pkl']

# %%
def load_dataset(config: dict):
    x_train = pickle_load(config["train_set_path"][0])
    y_train = pickle_load(config["train_set_path"][1])

    x_valid = pickle_load(config["valid_set_path"][0])
    y_valid = pickle_load(config["valid_set_path"][1])

    x_test = pickle_load(config["test_set_path"][0])
    y_test = pickle_load(config["test_set_path"][1])

    return x_train, y_train, x_valid, y_valid, x_test, y_test

# %%
x_train, y_train, x_valid, y_valid, x_test, y_test = load_dataset(config)
